# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.rcParams['figure.facecolor'] = 'w'
plt.style.use('dark_background')
import seaborn as sns
import random

# %%
def f(x):
    return np.exp(-(x-5)**2/2)

def q(x):
    return 1.

def q2(x):
    return 1.3*np.ones(len(x))

# %%
x_axis = np.linspace(0, 10, 100)
plt.plot(x_axis, f(x_axis));
plt.plot(x_axis, q2(x_axis));

# %% [markdown]
# $$ \lambda = \sup_x \frac{f(x)}{q(x)} $$

# %%
np.random.seed(42)
k = 1.3
prop_samples = np.random.uniform(low=0.0, high=10, size=10000)
samples_accepted = []
for x0 in prop_samples:
    u = np.random.uniform(low=0.0, high=1, size=1)
    r = f(x0) / k #(k*q(x0))
    if u <= r:
        samples_accepted.append(x0)
    # print(xs, u)
len(prop_samples), len(samples_accepted), len(samples_accepted)/len(prop_samples)
# Out:
# (10000, 1966, 0.1966)

# %%
fig, ax = plt.subplots(figsize=(10, 5), ncols=1)
xmin, xmax = -0.5, 10.5
# ymin, ymax = 0, 0.5

# ax.hist(prop_samples, density=0, bins=20, histtype='step', label='q(x)')
ax.hist(samples_accepted, density=True, bins=20, histtype='step', label='sample distribution')
ax.legend()
ax.set(xlabel='x', ylabel='counts', xlim=[xmin,xmax], )#ylim=[ymin,ymax])
ax.grid(lw=1, alpha=0.2, zorder=0)
    
# fig.savefig('../plots/pen-draw-distributions-0-4.pdf', bbox_inches='tight')

# %%
def f(x):
    return np.exp(-(x-5)**2/2) + 0.3*np.exp(-(x-7)**2/0.1)

x_axis = np.linspace(0, 10, 100)
plt.plot(x_axis, f(x_axis));
plt.plot(x_axis, q2(x_axis));

# %%
np.random.seed(42)
k = 1.3
prop_samples = np.random.uniform(low=0.0, high=10, size=100000)
samples_accepted = []
for x0 in prop_samples:
    u = np.random.uniform(low=0.0, high=1, size=1)
    r = f(x0) / k #(k*q(x0))
    if u <= r:
        samples_accepted.append(x0)
    # print(xs, u)
len(prop_samples), len(samples_accepted), len(samples_accepted)/len(prop_samples)
# Out:
# (100000, 20549, 0.20549)

# %%
fig, ax = plt.subplots(figsize=(10, 5), ncols=1)
xmin, xmax = -0.5, 10.5
# ymin, ymax = 0, 0.5

# ax.hist(prop_samples, density=0, bins=20, histtype='step', label='q(x)')
ax.hist(samples_accepted, density=True, bins=25, histtype='step', label='sample distribution')
ax.legend()
ax.set(xlabel='x', ylabel='counts', xlim=[xmin,xmax], )#ylim=[ymin,ymax])
ax.grid(lw=1, alpha=0.2, zorder=0)
    
# fig.savefig('../plots/pen-draw-distributions-0-4.pdf', bbox_inches='tight')
